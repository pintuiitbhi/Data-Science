# %%
                                                      IIT Bhilai 
                                                    ASSIGNMENT-01  
                                                Machine Learning: CS550
        Group Member: 
                    Akash Singh           : Btech EE  | 11640120  | 3rd Year 
                    Pintu Kumar           : Btech EE  | 11640650  | 3rd Year
                    Siddharth S. Singh    : Btech CSE | 11641000  | 3rd Year

# %% [markdown]
# (Click on the below links to navigate to different sections of the notebook)
# # **Overview**
# - <a href="#1">1. Introduction</a>
# - <a href="#2">2. Import the required packages</a>
# - <a href="#3">3. Import the Dataset</a>
# - <a href="#4">4. Explanatory Data Analysis</a>
#     - <a href="#4-1">4.1 Distribution of Smoker</a>
#     - <a href="#4-2">4.2 Distribution of BMI</a>
#     - <a href="#4-3">4.3 Distribution of Charges</a>
#     - <a href="#4-4">4.4 Distribution of Age</a>
#     - <a href="#4-5">4.5 Histogram of features</a>
#     - <a href="#4-6">4.6 Distribution of Sex in training set</a>
# - <a href="#5">5. Preprocessing the Dataset</a>
#     - <a href="#5-1">5.1 Check for NULLs</a>
#     - <a href="#5-2">5.2 Remove Outliers</a>
#     - <a href="#5-3">5.3 Feature Scaling</a>
#     - <a href="#5-4">5.4 Encoding the categorical data (one hot Encoding)</a>
#     - <a href="#5-5">5.5 Feature Importance</a>
#     - <a href="#5-6">5.6 Correlation Matrix</a>
#     - <a href="#5-7">5.7 Pairplot of different features</a>
#     - <a href="#5-8">5.8 Feature Selection</a>
# - <a href="#6">6. Function to make predictions of the output given the input feature</a>
#
# - <a href="#7">7. Function to evaluate the model</a>
#
# - <a href="#8">8.  Divide the dataset into training, cross-validation and testing data </a>
#
#     - <a href="#8-1">8.1 Holdout method with random sampling</a>
#         - <a href="#8-1A">A. Linear Regression Model</a>
#             - <a href="#8-1Aa"> Residual Plot & Scatter Plot</a>
#         - <a href="#8-1B">B. Ridge Regression</a>
#             - <a href="#8-1Ba"> Residual Plot & Scatter Plot </a>
#         - <a href="#8-1C">C. Random Forest</a>
#             - <a href="#8-1Ca"> Residual Plot & Scatter Plot</a>
#         - <a href="#8-1D">D. Support Vector Regression</a>
#             - <a href="#8-1Da"> Residual Plot & Scatter Plot </a>
#
#     - <a href="#8-2">8.2 Stratified Holdout method with random sampling</a>
#         - <a href="#8-2A">A. Linear Regression Model</a>
#             - <a href="#8-2Aa"> Residual Plot & Scatter Plot</a>
#         - <a href="#8-2B">B. Ridge Regression</a>
#             - <a href="#8-2Ba"> Residual Plot & Scatter Plot</a>
#         - <a href="#8-2C">C. Random Forest</a>
#             - <a href="#8-2Ca"> Residual Plot & Scatter Plot</a>
#         - <a href="#8-2D">D. Support Vector Regression</a>
#             - <a href="#8-2Da"> Residual Plot & Scatter Plot</a>
#
#     - <a href="#8-3">8.3 Stratified k-fold Cross-validation</a>
#         - <a href="#8-3A">A. Linear Regression Model</a>
#             - <a href="#8-3Aa"> Residual Plot & Scatter Plot</a>
#         - <a href="#8-3B">B. Ridge Regression</a>
#             - <a href="#8-3Ba"> Residual Plot & Scatter Plot</a>
#         - <a href="#8-3C">C. Random Forest</a>
#             - <a href="#8-3Ca"> Residual Plot & Scatter Plot</a>
#         - <a href="#8-3D">D. Support Vector Regression</a>
#             - <a href="#8-3Da"> Residual Plot & Scatter Plot</a>
#
#     - <a href="#8-4">8.4 Bootstrapping</a>
#         - <a href="#8-4A">A. Linear Regression Model</a>
#             - <a href="#8-4Aa"> Residual Plot & Scatter Plot</a>
#         - <a href="#8-4B">B. Ridge Regression</a>
#             - <a href="#8-4Ba"> Residual Plot & Scatter Plot</a>
#         - <a href="#8-4C">C. Random Forest</a>
#             - <a href="#8-4Ca"> Residual Plot & Scatter Plot</a>
#         - <a href="#8-4D">D. Support Vector Regression</a>
#             - <a href="#8-4Da"> Residual Plot & Scatter Plot</a>
#
# - <a href="#9">9.[Conclusion]Comparison of Performance of Model using Different Splitting methods</a>
# - <a href="#10">10. Best Regression Model</a>

# %% [markdown]
# ## <a id="1"> 1. Introduction </a>

# %% [markdown]
# In order to create a ML model to solve any problem ,  **we must have the domain  knowledge of the problem.** In our case it is related to *"insurance policy"* and the  problem is to *predict medical insurance cost using a regression model.*
#
# So let's have some knowledge of "insurance".  [Insurance](http://https://en.wikipedia.org/wiki/Insurance) is a means of **protection from financial loss .** (source : wikipedia) An entity which provides insurance is known as an insurer, *insurance company,* insurance carrier or underwriter. A person or entity who buys insurance is known as an insured or as a *policyholder.* The insured receives a contract, called the *insurance policy,* which details the conditions and circumstances under which the insurer will compensate the insured.
# If the insured experiences a loss which is potentially covered by the insurance policy, the insured submits a claim to the insurer for processing by a claims adjuster.
# [Health insurance](http://https://en.wikipedia.org/wiki/Health_insurance) is insurance that  **covers the whole or a part of the risk of a person incurring medical expenses, spreading the risk over a large number of persons**.

# %% [markdown]
# ## <a id="2">2. Import the required packages </a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split # for splitting the dataset in train,test and validation
from sklearn.linear_model import LinearRegression # for linear regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn import linear_model 
from sklearn.linear_model import Ridge
#from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error # for calcualting mse
#from sklearn.metrics import r2_score
from sklearn.cross_validation import StratifiedKFold # to implement stratifiedKFold
from sklearn import preprocessing
#from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt #for plotting
import seaborn as sns
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')
# import os
# print(os.listdir("../input")) #dataset available in 'input' folder

# %% [markdown]
# Let's first import the dataset and display for overview of differnent columns  in the table.

# %% [markdown]
# ## <a id="3">3. Import the dataset and read it </a>

# %%
#import dataset in variable insurance
insurance = pd.read_csv('insurance.csv')
insurance = insurance.sample(frac=1).reset_index(drop=True)# shuffle
display(insurance.head(10))
print(insurance.info())
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   42  female  23.37         0    yes  northeast  19964.7463
# 1   47    male  36.08         1    yes  southeast  42211.1382
# 2   34  female  29.26         3     no  southeast   6184.2994
# 3   41    male  30.78         3    yes  northeast  39597.4072
# 4   59    male  27.50         1     no  southwest  12333.8280
# 5   44    male  39.52         0     no  northwest   6948.7008
# 6   58  female  22.77         0     no  southeast  11833.7823
# 7   26    male  32.90         2    yes  southwest  36085.2190
# 8   49    male  37.51         2     no  southeast   9304.7019
# 9   30    male  35.30         0    yes  southwest  36837.4670
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB
# None

# %% [markdown]
# So we have the following input features  in the dataset
# - **age:** age of primary beneficiary
# - **sex:** insurance contractor gender, female, male
# - **bmi:** Body mass index, providing an understanding of body, weights that are relatively high or low relative to height, objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9
# - **children:** Number of children covered by health insurance / Number of dependents
# smoker: Smoking
# - **region:**  the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
# - **charges:**  Individual medical costs billed by health insurance
#
# The number of rows are 1338 and columns are 7.
# **Target variable** is **charges**.

# %%
insurance.shape
# Out:
# (1338, 7)

# %% [markdown]
# As we can see that we have less number of data, we have a chance of overfitting the model. Now let's do explanatory data analysis.

# %% [markdown]
# Types of the input feature

# %%
insurance.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# As we can see we have categorical features also. So first we need to do
# encoding of categorical feature. It will be helpful during  training of the model.

# %% [markdown]
# **Statistics of numerical columns** :

# %%
insurance.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %% [markdown]
# It seems that  "charges" is more spread (12110.01) . 75% percentile is 16639 and maximum is 63770.4280. So it has outlier .

# %%
insurance.groupby(insurance["smoker"]).mean()
# Out:
#               age        bmi  children       charges
# smoker
# no      39.385338  30.651795  1.090226   8434.268298
# yes     38.514599  30.708449  1.113139  32050.231832

# %%
insurance.groupby(insurance["region"]).count()
# Out:
#            age  sex  bmi  children  smoker  charges
# region
# northeast  324  324  324       324     324      324
# northwest  325  325  325       325     325      325
# southeast  364  364  364       364     364      364
# southwest  325  325  325       325     325      325

# %% [markdown]
# ## <a id="4">4. Explanatory Data Analysis </a>

# %% [markdown]
# ### <a id="4-1">4.1 Distribution of Smoker</a>

# %%
import matplotlib.ticker as mtick # For specifying the axes tick format 
ax = (insurance['smoker'].value_counts()*100.0 /len(insurance))\
.plot.pie(autopct='%.1f%%', labels = ['no', 'yes'],figsize =(5,5), fontsize = 12 )                                                                           
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylabel('Smoker',fontsize = 12)
ax.set_title('% Smoker', fontsize = 12)
# Out:
# Text(0.5,1,'% Smoker')

# %% [markdown]
# majority on people is non-smoker.

# %% [markdown]
# ### <a id="4-2">4.2 Distribution of BMI</a>

# %%
sns.distplot(insurance["bmi"])

# %% [markdown]
# "bmi" is normally distributeded. So it will help the model in prediction.

# %% [markdown]
# ### <a id="4-3">4.3 Distribution of Charges</a>

# %%
sns.distplot(insurance["charges"])

# %% [markdown]
# "charges" has outliers. So we need to remove them for better performance of the model.

# %% [markdown]
# ### <a id="4-4">4.4 Distribution of Age</a>

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of age in training set")
ax=sns.distplot(insurance["age"])

# %%
# temp_age_charges=pd.DataFrame()
# temp_age_charges["age"]=X_train["age"]
# temp_age_charges["charges"]=Y_train
_ = sns.lmplot("age", "charges", data=insurance, fit_reg=True)

# %%
# temp_bmi_charges=pd.DataFrame()
# temp_bmi_charges["bmi"]=X_train["bmi"]
# temp_bmi_charges["charges"]=Y_train
_ = sns.lmplot("bmi", "charges", data=insurance, fit_reg=True)

# %% [markdown]
# ### <a id="4-5">4.5 Histogram of Features</a>

# %%
insurance.hist(figsize=(15, 10))
plt.show()

# %% [markdown]
# ### <a id="4-6">4.6 Distribution of Sex in training set</a>

# %%
ax = sns.countplot(x="sex", hue="sex", data=insurance)

# %% [markdown]
# ## <a id="5" > 5. Preprocessing the Dataset</a>

# %% [markdown]
# ### <a id="5-1" > 5.1 Check for NULLS</a>

# %%
insurance.isnull().sum(axis = 0)
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# There is no  missing values.

# %% [markdown]
# ### <a id="5-2" > 5.2 Remove Outliers</a>

# %%
cols=[ 'bmi', 'charges']
#Determine outliers in dataset

for i in cols:
    quartile_1,quartile_3 = np.percentile(insurance[i],[25,75])
    quartile_f,quartile_l = np.percentile(insurance[i],[1,99])
    IQR = quartile_3-quartile_1
    lower_bound = quartile_1 - (1.5*IQR)
    upper_bound = quartile_3 + (1.5*IQR)
    print(i,lower_bound,upper_bound,quartile_f,quartile_l)

    insurance[i].loc[insurance[i] < lower_bound] = quartile_f
    insurance[i].loc[insurance[i] > upper_bound] = quartile_l
# Out:
# bmi 13.7 47.290000000000006 17.89515 46.40789999999996
# charges -13109.1508975 34489.350562499996 1252.97273 48537.480725999994

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

insurance1=remove_outlier(insurance, 'bmi')
insurance1=remove_outlier(insurance1, 'charges')
insurance=insurance1

# %% [markdown]
# ### <a id="5-3" > 5.3 Feature Scaling</a>

# %%
#insurance['charges']=(insurance['charges']-insurance['charges'].min())/(insurance['charges'].max()-insurance['charges'].min())
insurance['bmi']=(insurance['bmi']-insurance['bmi'].min())/(insurance['bmi'].max()-insurance['bmi'].min())
insurance.head()
# Out:
#    age     sex       bmi  children smoker     region     charges
# 0   42  female  0.240663         0    yes  northeast  19964.7463
# 2   34  female  0.431958         3     no  southeast   6184.2994
# 4   59    male  0.374797         1     no  southwest  12333.8280
# 5   44    male  0.765184         0     no  northwest   6948.7008
# 6   58  female  0.221176         0     no  southeast  11833.7823

# %%
insurance.hist(figsize=(15, 10))
plt.show()
insurance.describe().T
# Out:
#            count         mean          std        min          25%  \
# age       1199.0    38.989992    14.068040    18.0000    26.000000
# bmi       1199.0     0.458611     0.193755     0.0000     0.319584
# children  1199.0     1.084237     1.214304     0.0000     0.000000
# charges   1199.0  9927.753402  7241.158309  1121.8739  4408.695900
#
#                   50%           75%        max
# age         39.000000     51.000000     64.000
# bmi          0.447386      0.580058      1.000
# children     1.000000      2.000000      5.000
# charges   8410.046850  12953.594600  34472.841

# %% [markdown]
# ### <a id="5-4" > 5.4 Encoding the categorical data (one hot Encoding)</a>

# %%
insurance=pd.get_dummies(insurance,drop_first=True)
insurance.head()
# Out:
#    age       bmi  children     charges  sex_male  smoker_yes  \
# 0   42  0.240663         0  19964.7463         0           1
# 2   34  0.431958         3   6184.2994         0           0
# 4   59  0.374797         1  12333.8280         1           0
# 5   44  0.765184         0   6948.7008         1           0
# 6   58  0.221176         0  11833.7823         0           0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 0
# 2                 0                 1                 0
# 4                 0                 0                 1
# 5                 1                 0                 0
# 6                 0                 1                 0

# %% [markdown]
# ### <a id="5-5" > 5.5  Feature Importance</a>

# %%
#using randomforest to find the feature importance
train_y = insurance['charges'].values
train_X = insurance.drop(['charges'], axis=1)

from sklearn import ensemble
model = ensemble.RandomForestRegressor(n_estimators=200, max_depth=10, min_samples_leaf=4, max_features=0.2, n_jobs=-1, random_state=0)
model.fit(train_X, train_y)
feat_names = train_X.columns.values

importances = model.feature_importances_
std = np.std([tree.feature_importances_ for tree in model.estimators_], axis=0)
indices = np.argsort(importances)[::-1][:20]

plt.figure(figsize=(12,5))
plt.title("Feature importances")
plt.bar(range(len(indices)), importances[indices], color="g", align="center")
plt.xticks(range(len(indices)), feat_names[indices], rotation='vertical')
plt.xlim([-1, len(indices)])
plt.show()

# %% [markdown]
# ### <a id="5-6" > 5.6 Correlation Matrix</a>

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(10,10)) #controls the graph size
plt.title('Pearson Correlation of Features', y=1, size=20) #"size" controls the title size

sns.heatmap(insurance.astype(float).corr(),linewidths=2,vmax=1.0, 
            square=True, cmap=colormap, linecolor='red', annot=True)

# %% [markdown]
# As we can see from the above correlation matrix "children" is very less correlated with the target variable "charges" , followed by "sex_male". So we can remove them .
#
# Remove very less correlated features with the target variable. As we can see from the
# above correlation matrix "region" is very less correlated.

# %% [markdown]
# ### <a id="5-7" > 5.7 Pairplot of different features</a>

# %% [markdown]
# Pairplot to visualize the realtionship between the target and independent features

# %%
sns.pairplot(insurance, x_vars=["bmi", "age",'children'], y_vars=["charges"],
              aspect=1, kind="reg");

# %% [markdown]
# ### <a id="5-8" > 5.8 Feature Selection</a>

# %%
#Selected Features
cols= ['smoker_yes','age','bmi','children','region_southwest']
X=insurance[cols]
y=insurance['charges']
X.shape
# Out:
# (1199, 5)

# %% [markdown]
# ## <a id="6"> 6. Function to make predictions of the output given the input feature. </a>

# %% [markdown]
# Define functions to calculate train error, validation error and finally to calculate error on test set.

# %%
def calc_train_error(X_train, y_train, model):
    '''returns in-sample error for already fit model.'''
    predictions = model.predict(X_train)
    mse = mean_squared_error(y_train, predictions)
    rmse = np.sqrt(mse)
    return rmse
    
def calc_validation_error(X_test, y_test, model):
    '''returns out-of-sample error for already fit model.'''
    predictions = model.predict(X_test)
    mse = mean_squared_error(y_test, predictions)
    rmse = np.sqrt(mse)
    return rmse
    
def calc_metrics(X_train, y_train, X_test, y_test, model):
    '''fits model and returns the RMSE for in-sample error and out-of-sample error'''
    model.fit(X_train, y_train)
    train_error = calc_train_error(X_train, y_train, model)
    validation_error = calc_validation_error(X_test, y_test, model)
    return train_error, validation_error

# %% [markdown]
# Now, we will create a general function to implement linear regression model and fit the model to training data set .

# %%
def regression_model(X_train, Y_train, X_validation,Y_validation,X_test, Y_test):
    ''' Input:
        X_train : independent training data
        Y_train : target variable for trainig
        X_validation: validation dataset
        Y_validation: validation target variable
        evaluate: accepts boolean value "true" or "fale". If true then function will predict the test accuracy 
                instead of training and validation error'''
    linear_Model = linear_model.LinearRegression(fit_intercept=True) #creating model
    linear_Model.fit(X_train,Y_train,) # fitting the model

    train_error_rmse = calc_train_error(X_train, Y_train, linear_Model)
    valid_error_rmse= calc_validation_error(X_validation, Y_validation, linear_Model)
    train_error_rmse, valid_error_mse= round(train_error_rmse, 3) ,round(valid_error_rmse, 3)
    print('RMSE - train error: {} | validation error: {}'.format(train_error_rmse, valid_error_rmse))
    
                                                                                 np.sqrt(mean_squared_error(y_pred,Y_test))))
    accuracy = linear_Model.score(X_validation,Y_validation)
    print('Accuracy :',format(round(accuracy,3),"%"))
   
    return linear_Model,train_error_rmse, valid_error_mse

# %% [markdown]
# ## <a id="7"> 7. Function to evaluate the model </a>

# %%
def evaluate(X_train, Y_train, X_test, Y_test, train_error,validation_error, model):

    new_train_error = mean_squared_error(Y_train,model.predict(X_train))
    new_train_error = np.sqrt(new_train_error)
   # new_validation_error = mean_squared_error(Y_validation, model.predict(X_validation))
    new_test_error = mean_squared_error(Y_test, model.predict(X_test))
    new_test_error = np.sqrt(new_test_error)

    
    print('Comparison')
    print('-'*50)
    print('ORIGINAL ERROR')
    print('train error: {} | validation error: {}\n'.format(round(train_error,3), round(validation_error,3)))
    accuracy = model.score(X_validation,Y_validation)
    print('Accuracy :',format(round(accuracy,3),"%"))
    print('-' * 50)
    print('FINAL ERROR OF MODEL')
    print('train error: {} | test error: {}'.format(round(new_train_error,3), round(new_test_error,3)))
    accuracy = model.score(X_test,Y_test)
    print('Accuracy :',format(round(accuracy,3),"%"))
    y_pred= model.predict(X_test)
    return y_pred, accuracy,new_test_error

# %% [markdown]
# ## <a id="8"> 8.  Divide the data into training, cross-validation and testing data </a>

# %%
print("Independent features")
display(X.head())
print("-"*100)
print("Target variable")
display(y.head())
# Out:
# Independent features
#    smoker_yes  age       bmi  children  region_southwest
# 0           1   42  0.240663         0                 0
# 2           0   34  0.431958         3                 0
# 4           0   59  0.374797         1                 1
# 5           0   44  0.765184         0                 0
# 6           0   58  0.221176         0                 0
# ----------------------------------------------------------------------------------------------------
# Target variable
# 0    19964.7463
# 2     6184.2994
# 4    12333.8280
# 5     6948.7008
# 6    11833.7823
# Name: charges, dtype: float64

# %% [markdown]
# The target variable is continuous. So to split the dataset using stratify we need to convert "charges" into bins. Therefore we will add

# %% [markdown]
# ## <a id="8-1"> 8.1 Holdout method with random sampling </a>

# %% [markdown]
# Hold-out validation is simple. Assuming that all data points are i.i.d. (independently and identically distributed), we simply randomly hold out part of the data for validation. We train the model on the larger portion of the data and evaluate validation metrics on the smaller hold-out set.
#
# Computationally speaking, hold-out validation is simple to program and fast to run. The downside is that it is less powerful statistically. The validation results are derived from a small subset of the data, hence its estimate of the generalization error is less reliable. It is also difficult to compute any variance information or confidence intervals on a single dataset.
#
# Use hold-out validation when there is enough data such that a subset can be held out, and this subset is big enough to ensure reliable statistical estimates.

# %%
X_intermediate, X_test, Y_intermediate, Y_test = train_test_split(X, 
                                                                  y, 
                                                                  shuffle=True,
                                                                  test_size=0.1 
                                                                  )

# train/validation split (gives us train and validation sets)
X_train, X_validation, Y_train, Y_validation = train_test_split(X_intermediate,
                                                                Y_intermediate,
                                                                shuffle=False,
                                                                test_size=0.2
                                                                )

# %%
# print proportions
#holdoutA=[] #to store accuracy
holdoutE=[] #to store rmse error
print('train: {}% | validation: {}% | test {}%'.format(round(len(Y_train)/len(y),2),
                                                       round(len(Y_validation)/len(y),2),
                                                       round(len(Y_test)/len(y),2)))
# Out:
# train: 0.72% | validation: 0.18% | test 0.1%

# %% [markdown]
# ### <a id="8-1A"> A. [Holdout method]Linear Regression Model </a>

# %% [markdown]
# Let's create linear regression model and fit  <a href="#7-1"> data </a> to it that is available to us after holdout i.e splitting. And also print the validation and training error using the function that we created earlier  -> <a href="#5">  Function to make predictions of the output given the input feature. </a>

# %%
model , train_error,validation_error= regression_model(X_train, Y_train, X_validation,Y_validation,X_test,Y_test)
# Out:
# RMSE - train error: 4494.875 | validation error: 4311.002478104637
# Accuracy : 65.100000%

# %% [markdown]
# #### [Holdout] [Linear Regression] RMSE

# %%
y_pred,accuracy,test_error=evaluate(X_intermediate, Y_intermediate, X_test, Y_test, train_error,validation_error, model)
#holdoutA.append(accuracy)
holdoutE.append(test_error)
# Out:
# Comparison
# --------------------------------------------------
# ORIGINAL ERROR
# train error: 4494.875 | validation error: 4311.002
#
# Accuracy : 65.100000%
# --------------------------------------------------
# FINAL ERROR OF MODEL
# train error: 4458.674 | test error: 5487.97
# Accuracy : 51.400000%

# %%
def model_scatter_plot(y_pred,Y_test):
    model_table = pd.DataFrame(y_pred,Y_test).reset_index()
    model_table.columns=['Y_test','y_pred']
    #Model Graph
    sns.lmplot(x = 'Y_test',y='y_pred',data = model_table,size=6,aspect=1.5,
           scatter_kws={"s": 70, "alpha": 1,'edgecolor':'black'},fit_reg=True)
    plt.title('Analysis of True and Predicted Cost',fontsize=14)
    plt.xlabel('Y_test',fontsize=12)
    plt.ylabel('y_pred',fontsize=12)
    #plt.scatter(y_test,y_pred)
    return plt.show()

print("[Holdout][Linear Regression]")
model_scatter_plot(y_pred,Y_test)
# Out:
# [Holdout][Linear Regression]

# %% [markdown]
# ###  <a id="8-1Aa"> [Holdout] Residual Plot for Linear Regression </a>

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Holdout] Residual Plot for Linear Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,y_pred) ## regression Residual Plot for linear regression model using bootstrapping

# %% [markdown]
# ## <a id="8-1B" >B. [Holdout Method] Ridge Regression</a>

# %% [markdown]
# **Hyperparameter tuning ** : parameter "alpha"  for ridger regression using validation set

# %%
#hyperparameters
para=np.linspace(0.01,10,100)
error=dict()

#tuning hyperparameter
print("Parameter   RMSE Error")
print("-"*25)
for parameter in para:
    ridge = Ridge(fit_intercept=True, alpha=parameter)
    ridge.fit(X_train,Y_train)
    
    terr = calc_train_error(X_train,Y_train,ridge)
    verr = calc_validation_error(X_validation,Y_validation,ridge)
    total_error =np.abs(terr-verr)
    error[parameter]= total_error
    p= min(error,key = error.get)
    print("{:.3f}        {:.3f}".format(parameter,error[parameter]))
    
print("Best parameter after validation: {:.3f}".format(p))
# Out:
# Parameter   RMSE Error
# -------------------------
# 0.010        183.869
# 0.111        183.828
# 0.212        183.786
# 0.313        183.743
# 0.414        183.697
# 0.515        183.650
# 0.615        183.602
# 0.716        183.552
# 0.817        183.500
# 0.918        183.447
# 1.019        183.393
# 1.120        183.337
# 1.221        183.279
# 1.322        183.220
# 1.423        183.160
# 1.524        183.098
# 1.625        183.035
# 1.725        182.970
# 1.826        182.904
# 1.927        182.837
# 2.028        182.768
# 2.129        182.698
# 2.230        182.626
# 2.331        182.553
# 2.432        182.479
# 2.533        182.403
# 2.634        182.326
# 2.735        182.248
# 2.835        182.169
# 2.936        182.088
# 3.037        182.006
# 3.138        181.923
# 3.239        181.838
# 3.340        181.753
# 3.441        181.666
# 3.542        181.578
# 3.643        181.488
# 3.744        181.398
# 3.845        181.306
# 3.945        181.213
# 4.046        181.119
# 4.147        181.024
# 4.248        180.927
# 4.349        180.830
# 4.450        180.731
# 4.551        180.631
# 4.652        180.531
# 4.753        180.429
# 4.854        180.326
# 4.955        180.222
# 5.055        180.116
# 5.156        180.010
# 5.257        179.903
# 5.358        179.795
# 5.459        179.685
# 5.560        179.575
# 5.661        179.464
# 5.762        179.351
# 5.863        179.238
# 5.964        179.123
# 6.065        179.008
# 6.165        178.892
# 6.266        178.775
# 6.367        178.656
# 6.468        178.537
# 6.569        178.417
# 6.670        178.296
# 6.771        178.174
# 6.872        178.051
# 6.973        177.928
# 7.074        177.803
# 7.175        177.677
# 7.275        177.551
# 7.376        177.424
# 7.477        177.296
# 7.578        177.167
# 7.679        177.037
# 7.780        176.906
# 7.881        176.775
# 7.982        176.642
# 8.083        176.509
# 8.184        176.375
# 8.285        176.240
# 8.385        176.105
# 8.486        175.969
# 8.587        175.831
# 8.688        175.694
# 8.789        175.555
# 8.890        175.415
# 8.991        175.275
# 9.092        175.134
# 9.193        174.993
# 9.294        174.850
# 9.395        174.707
# 9.495        174.563
# 9.596        174.419
# 9.697        174.274
# 9.798        174.128
# 9.899        173.981
# 10.000        173.834
# Best parameter after validation: 10.000

# %% [markdown]
# Error plot of training and validation for finding best parameter of ridge regression.

# %%
#plot of error
def plotErr(select,X_train,Y_train,para_range,X_validation,Y_validation):   
    #Setup arrays to store training and test accuracies
    para = np.linspace(0.01,para_range,100)
    train_accuracy =np.empty(len(para))
    test_accuracy = np.empty(len(para))

    
    
    for i,k in enumerate(para):
        mod = [Ridge(fit_intercept=True, alpha=k),RandomForestRegressor(max_depth=k, random_state=0),SVR(C=k, epsilon=0.2)]
        m = mod[select]
        m.fit(X_train,Y_train)
        train_accuracy[i]= calc_train_error(X_train, Y_train, m)
        test_accuracy[i] = calc_validation_error(X_validation, Y_validation,m)
       

    #Generate plot
    plt.figure()
    plt.figure(figsize=(8,8))
    plt.title('error plot for training and validation')
    plt.plot(para, test_accuracy, label='validation error')
    plt.plot(para, train_accuracy, label='train error')
    plt.legend()
    plt.xlabel('Value of alpha')
    plt.ylabel('RMSE')
    plt.show()
print("[Holdout][Ridge Regression]")    
plotErr(0,X_train,Y_train,10,X_validation,Y_validation)
# Out:
# [Holdout][Ridge Regression]

# %%
# Create ridge regression model
ridge = Ridge(fit_intercept=True, alpha=p)

# %%
# Train the model using the training set
ridge.fit(X_train,Y_train)
# Out:
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
# Compute RMSE on training data
p = ridge.predict(X_train)
err = p-Y_train
total_error = np.dot(err,err)
rmse_train = np.sqrt(total_error/len(p))
print("[Holdout][Ridge Regression]\nTraining error : {:.2f}".format(rmse_train))
# Out:
# [Holdout][Ridge Regression]
# Training error : 4522.67

# %%
#Compute RMSE on validation data
p = ridge.predict(X_validation)
err = p-Y_validation
total_error = np.dot(err,err)
rmse_validation = np.sqrt(total_error/len(p))
print("[Holdout][Ridge Regression]\nValidation error : {:.2f}".format(rmse_validation))
#accuracy = p.score(X_validation,Y_validation)
# Out:
# [Holdout][Ridge Regression]
# Validation error : 4348.83

# %%
#Compute RMSE on test data
p = ridge.predict(X_test)
err = p-Y_test
total_error = np.dot(err,err)
rmse_test = np.sqrt(total_error/len(p))
holdoutE.append(rmse_test)
print("[Holdout][Ridge Regression]\ntest error : {:.2f}".format(rmse_test))
# Out:
# [Holdout][Ridge Regression]
# test error : 5520.10

# %%
print("[Holdout][Ridge Regression]")
model_scatter_plot(p,Y_test)
# Out:
# [Holdout][Ridge Regression]

# %% [markdown]
# ### <a id="8-1Ba"> [Holdout] Residual Plot for Ridge Regression </a>

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Holdout] Residual Plot for Ridge Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,p) ## regression Residual Plot for Ridge Regression model using bootstrapping

# %% [markdown]
# ## <a id="8-1C" >C. [Holdout Method] Random Forest</a>

# %% [markdown]
# **Hyperparameter tuning ** : parameter "max depth"  for random forest using validation set

# %%
#hyperparameters
para=np.arange(2,100,1)
error=dict()

#tuning hyperparameter
print("Parameter   RMSE Error")
print("-"*25)
for parameter in para:
    regr = RandomForestRegressor(max_depth=parameter, random_state=0)
    regr.fit(X_train,Y_train)
    
    terr = calc_train_error(X_train,Y_train,regr)
    verr = calc_validation_error(X_validation,Y_validation,regr)
    total_error =np.abs(terr-verr)
    error[parameter]= total_error
    p= min(error,key = error.get)
    print("{:.3f}        {:.3f}".format(parameter,error[parameter]))
    
print("Best parameter after validation: {:.3f}".format(p))
# Out:
# Parameter   RMSE Error
# -------------------------
# 2.000        310.739
# 3.000        273.890
# 4.000        208.146
# 5.000        93.264
# 6.000        671.655
# 7.000        971.360
# 8.000        1390.185
# 9.000        1831.872
# 10.000        2204.163
# 11.000        2332.769
# 12.000        2521.739
# 13.000        2594.469
# 14.000        2586.769
# 15.000        2612.264
# 16.000        2644.877
# 17.000        2634.125
# 18.000        2720.989
# 19.000        2715.003
# 20.000        2684.954
# 21.000        2685.329
# 22.000        2685.329
# 23.000        2685.329
# 24.000        2685.329
# 25.000        2685.329
# 26.000        2685.329
# 27.000        2685.329
# 28.000        2685.329
# 29.000        2685.329
# 30.000        2685.329
# 31.000        2685.329
# 32.000        2685.329
# 33.000        2685.329
# 34.000        2685.329
# 35.000        2685.329
# 36.000        2685.329
# 37.000        2685.329
# 38.000        2685.329
# 39.000        2685.329
# 40.000        2685.329
# 41.000        2685.329
# 42.000        2685.329
# 43.000        2685.329
# 44.000        2685.329
# 45.000        2685.329
# 46.000        2685.329
# 47.000        2685.329
# 48.000        2685.329
# 49.000        2685.329
# 50.000        2685.329
# 51.000        2685.329
# 52.000        2685.329
# 53.000        2685.329
# 54.000        2685.329
# 55.000        2685.329
# 56.000        2685.329
# 57.000        2685.329
# 58.000        2685.329
# 59.000        2685.329
# 60.000        2685.329
# 61.000        2685.329
# 62.000        2685.329
# 63.000        2685.329
# 64.000        2685.329
# 65.000        2685.329
# 66.000        2685.329
# 67.000        2685.329
# 68.000        2685.329
# 69.000        2685.329
# 70.000        2685.329
# 71.000        2685.329
# 72.000        2685.329
# 73.000        2685.329
# 74.000        2685.329
# 75.000        2685.329
# 76.000        2685.329
# 77.000        2685.329
# 78.000        2685.329
# 79.000        2685.329
# 80.000        2685.329
# 81.000        2685.329
# 82.000        2685.329
# 83.000        2685.329
# 84.000        2685.329
# 85.000        2685.329
# 86.000        2685.329
# 87.000        2685.329
# 88.000        2685.329
# 89.000        2685.329
# 90.000        2685.329
# 91.000        2685.329
# 92.000        2685.329
# 93.000        2685.329
# 94.000        2685.329
# 95.000        2685.329
# 96.000        2685.329
# 97.000        2685.329
# 98.000        2685.329
# 99.000        2685.329
# Best parameter after validation: 5.000

# %%
print("[Holdout][Random Forest]")
plotErr(1,X_train,Y_train,100,X_validation,Y_validation)
# Out:
# [Holdout][Random Forest]

# %%
# Create random forest regression model
regr = RandomForestRegressor(max_depth=p, random_state=0)

# Train the model using the training set
regr.fit(X_train,Y_train)

# Compute RMSE on training data
p = regr.predict(X_train)
err = p-Y_train
total_error = np.dot(err,err)
rmse_train = np.sqrt(total_error/len(p))
print("[Holdout][Random Forest]\nTraining error : {:.2f}".format(rmse_train))

#Compute RMSE on validation data
p = regr.predict(X_validation)
err = p-Y_validation
total_error = np.dot(err,err)
rmse_validation = np.sqrt(total_error/len(p))
print("Validation error : {:.2f}".format(rmse_validation))
#accuracy = p.score(X_validation,Y_validation)
# Out:
# [Holdout][Random Forest]
# Training error : 3878.18
# Validation error : 3971.45

# %%
#Compute RMSE on test data
p = regr.predict(X_test)
err = p-Y_test
total_error = np.dot(err,err)
rmse_test = np.sqrt(total_error/len(p))
holdoutE.append(rmse_test)
print("[Holdout][Random Forest]\nTest error : {:.2f}".format(rmse_test))
# Out:
# [Holdout][Random Forest]
# Test error : 5510.90

# %%
print("[Holdout][Random Forest]")
model_scatter_plot(p,Y_test)
# Out:
# [Holdout][Random Forest]

# %% [markdown]
# ### <a id="8-1Ca">[Holdout] Residual Plot for Random Forest

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Holdout] Residual Plot for Random Forest', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,p) ## regression Residual Plot for Random Forest model using bootstrapping

# %% [markdown]
# ## <a id="8-1D" >D. [Holdout Method] Support Vector Regression</a>

# %% [markdown]
# **Hyperparameter tuning ** : parameter "C"  for support vector regression using validation set

# %%
#hyperparameters
para=np.linspace(1,10,100)
error=dict()

#tuning hyperparameter
print("Parameter   RMSE Error")
print("-"*25)
for parameter in para:
    sv = SVR(C=parameter)
    sv.fit(X_train,Y_train)
    
    terr = calc_train_error(X_train,Y_train,sv)
    verr = calc_validation_error(X_validation,Y_validation,sv)
    total_error =np.abs(terr-verr)
    error[parameter]= total_error
    p= min(error,key = error.get)
    print("{:.3f}        {:.3f}".format(parameter,error[parameter]))
    
print("Best parameter after validation: {:.3f}".format(p))
# Out:
# Parameter   RMSE Error
# -------------------------
# 1.000        204.817
# 1.091        204.974
# 1.182        205.168
# 1.273        205.371
# 1.364        205.575
# 1.455        205.778
# 1.545        205.981
# 1.636        206.184
# 1.727        206.383
# 1.818        206.579
# 1.909        206.770
# 2.000        206.960
# 2.091        207.151
# 2.182        207.336
# 2.273        207.517
# 2.364        207.696
# 2.455        207.862
# 2.545        208.029
# 2.636        208.195
# 2.727        208.362
# 2.818        208.528
# 2.909        208.695
# 3.000        208.861
# 3.091        209.027
# 3.182        209.194
# 3.273        209.360
# 3.364        209.527
# 3.455        209.693
# 3.545        209.859
# 3.636        210.026
# 3.727        210.192
# 3.818        210.358
# 3.909        210.525
# 4.000        210.691
# 4.091        210.857
# 4.182        211.024
# 4.273        211.200
# 4.364        211.392
# 4.455        211.584
# 4.545        211.797
# 4.636        212.025
# 4.727        212.252
# 4.818        212.480
# 4.909        212.708
# 5.000        212.936
# 5.091        213.164
# 5.182        213.391
# 5.273        213.619
# 5.364        213.847
# 5.455        214.075
# 5.545        214.302
# 5.636        214.530
# 5.727        214.755
# 5.818        214.957
# 5.909        215.159
# 6.000        215.362
# 6.091        215.564
# 6.182        215.766
# 6.273        215.968
# 6.364        216.164
# 6.455        216.355
# 6.545        216.547
# 6.636        216.738
# 6.727        216.930
# 6.818        217.122
# 6.909        217.313
# 7.000        217.505
# 7.091        217.696
# 7.182        217.888
# 7.273        218.080
# 7.364        218.271
# 7.455        218.463
# 7.545        218.655
# 7.636        218.846
# 7.727        219.038
# 7.818        219.229
# 7.909        219.421
# 8.000        219.613
# 8.091        219.793
# 8.182        219.971
# 8.273        220.149
# 8.364        220.334
# 8.455        220.525
# 8.545        220.718
# 8.636        220.907
# 8.727        221.100
# 8.818        221.292
# 8.909        221.471
# 9.000        221.653
# 9.091        221.844
# 9.182        222.035
# 9.273        222.224
# 9.364        222.407
# 9.455        222.591
# 9.545        222.774
# 9.636        222.957
# 9.727        223.141
# 9.818        223.324
# 9.909        223.507
# 10.000        223.691
# Best parameter after validation: 1.000

# %%
print("[Holdout][Support Vector Regression]")
plotErr(2,X_train,Y_train,100,X_validation,Y_validation)
# Out:
# [Holdout][Support Vector Regression]

# %%
# Create support vector regression model
sv = SVR(C=10)

# Train the model using the training set
sv.fit(X_train,Y_train)

# Compute RMSE on training data
p = sv.predict(X_train)
err = p-Y_train
total_error = np.dot(err,err)
rmse_train = np.sqrt(total_error/len(p))
print("[Holdout][Support Vector Regressor]\nTraining error : {:.2f}".format(rmse_train))

#Compute RMSE on validation data
p = sv.predict(X_validation)
err = p-Y_validation
total_error = np.dot(err,err)
rmse_validation = np.sqrt(total_error/len(p))
print("Validation error : {:.2f}".format(rmse_validation))
#accuracy = p.score(X_validation,Y_validation)
# Out:
# [Holdout][Support Vector Regressor]
# Training error : 7189.74
# Validation error : 7413.44

# %%
#Compute RMSE on test data
p = sv.predict(X_test)
err = p-Y_test
total_error = np.dot(err,err)
rmse_test = np.sqrt(total_error/len(p))
holdoutE.append(rmse_test)
print("[Holdout][Support Vector regressor]\nTest error : {:.2f}".format(rmse_test))
# Out:
# [Holdout][Support Vector regressor]
# Test error : 7946.23

# %%
print("[Holdout][Support Vector Regression]")
model_scatter_plot(p,Y_test)
# Out:
# [Holdout][Support Vector Regression]

# %% [markdown]
# ### <a id="8-1Ad"> [Holdout] Residual Plot for Support Vector Regression</a>

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Holdout] Residual Plot for Support Vector Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,p) ## regression Residual Plot for Support Vector Regression model using bootstrapping

# %% [markdown]
# ## <a id="8-2"> 8.2 Stratified holdout method </a>

# %% [markdown]
# The target variable is continuous. So to split the dataset using stratify we need to convert "charges" into bins.

# %%
#create bins
X["charges"] = y

bins = np.linspace(X.charges.min(),X.charges.max(),7)
charges_groups = np.digitize(X.charges,bins)

#Add bin information to the dataframe
X= X.assign(charge_groups = charges_groups)
X['charge_groups'] = pd.Categorical(X.charge_groups)

#Last bin has too few values to stratify, so we merge it with second last group and reduce the number of bins
X.charge_groups[X.charge_groups == 7]= 6
y_stratify= X["charge_groups"]
X.head()
#X["charge_groups"].unique()
X.groupby(X["charge_groups"]).count()
# Out:
#                smoker_yes  age  bmi  children  region_southwest  charges
# charge_groups
# 1                     482  482  482       482               482      482
# 2                     379  379  379       379               379      379
# 3                     160  160  160       160               160      160
# 4                      94   94   94        94                94       94
# 5                      55   55   55        55                55       55
# 6                      29   29   29        29                29       29
# 7                       0    0    0         0                 0        0

# %%
X_intermediateS, X_testS, Y_intermediateS, Y_testS = train_test_split(X, 
                                                                  y_stratify, 
                                                                  shuffle=True,
                                                                  test_size=0.2,
                                                                  stratify=y_stratify
                                                                  )

#train/validation split (gives us train and validation sets)
X_trainS, X_validationS, Y_trainS, Y_validationS = train_test_split(X_intermediateS,
                                                                Y_intermediateS,
                                                                shuffle=True,
                                                                test_size=0.2,
                                                                stratify=Y_intermediateS
                                                                )

#remove the "charges" and "charge_groups" column and separate target variable
X_str=X_intermediateS.copy()
y_str=Y_intermediateS
Y_intermediateS=X_intermediateS['charges']
del X_intermediateS["charges"]
del X_intermediateS["charge_groups"]
Y_trainS=X_trainS["charges"]
del X_trainS["charges"]
del X_trainS["charge_groups"]

Y_testS=X_testS["charges"]
del X_testS["charges"]
del X_testS["charge_groups"]
X_str.head()
# Out:
#      smoker_yes  age       bmi  children  region_southwest     charges  \
# 462           0   31  0.317636         0                 0  3756.62160
# 537           0   50  0.459727         1                 0  9910.35985
# 329           0   19  0.631374         0                 1  1263.24900
# 793           0   31  0.407275         5                 0  6799.45800
# 833           0   36  0.599870         2                 0  5584.30570
#
#     charge_groups
# 462             1
# 537             2
# 329             1
# 793             2
# 833             1

# %%
holdoutStf=[] #to store rmse error
print('train: {}% | validation: {}% | test {}%'.format(round(len(Y_trainS)/len(y),2),
                                                       round(len(Y_validationS)/len(y),2),
                                                       round(len(Y_testS)/len(y),2)))
# Out:
# train: 0.64% | validation: 0.16% | test 0.2%

# %% [markdown]
# ### <a id="8.2A"> A. [Stratified Holdout method]Linear Regression Model </a>

# %% [markdown]
# Let's create linear regression model and fit  <a href="#7-1"> data </a> to it that is available to us after holdout i.e splitting. And also print the validation and training error using the function that we created earlier  -> <a href="#5">  Function to make predictions of the output given the input feature. </a>

# %%
model , train_error,validation_error= regression_model(X_train, Y_train, X_validation,Y_validation,X_test,Y_test)
# Out:
# RMSE - train error: 4494.875 | validation error: 4311.002478104637
# Accuracy : 65.100000%

# %% [markdown]
# #### [Stratified Holdout] [Linear Regression] RMSE

# %%
y_pred,accuracy,test_error=evaluate(X_intermediate, Y_intermediate, X_test, Y_test, train_error,validation_error, model)
#holdoutA.append(accuracy)
holdoutStf.append(test_error)

def model_scatter_plot(y_pred,Y_test):
    model_table = pd.DataFrame(y_pred,Y_test).reset_index()
    model_table.columns=['Y_test','y_pred']
    #Model Graph
    sns.lmplot(x = 'Y_test',y='y_pred',data = model_table,size=6,aspect=1.5,
           scatter_kws={"s": 70, "alpha": 1,'edgecolor':'black'},fit_reg=True)
    plt.title('Analysis of True and Predicted Cost',fontsize=14)
    plt.xlabel('Y_test',fontsize=12)
    plt.ylabel('y_pred',fontsize=12)
    #plt.scatter(y_test,y_pred)
    return plt.show()

print("[Stratified Holdout][Linear Regression]")
model_scatter_plot(y_pred,Y_test)
# Out:
# Comparison
# --------------------------------------------------
# ORIGINAL ERROR
# train error: 4494.875 | validation error: 4311.002
#
# Accuracy : 65.100000%
# --------------------------------------------------
# FINAL ERROR OF MODEL
# train error: 4458.674 | test error: 5487.97
# Accuracy : 51.400000%
# [Stratified Holdout][Linear Regression]

# %% [markdown]
# ### <a id="8-2Aa">[Stratified Holdout] Residual Plot for Linear Regression</a>

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Stratified Holdout] Residual Plot for Linear Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,y_pred) ## regression Residual Plot for linear regression model using bootstrapping

# %% [markdown]
# ### <a id="8.2B"> B. [Stratified Holdout method]Ridge Regression </a>

# %% [markdown]
# **Hyperparameter tuning ** : parameter "alpha"  for ridger regression using validation set

# %%
#hyperparameters
para=np.linspace(0.01,10,100)
error=dict()

#tuning hyperparameter
print("Parameter   RMSE Error")
print("-"*25)
for parameter in para:
    ridge = Ridge(fit_intercept=True, alpha=parameter)
    ridge.fit(X_train,Y_train)
    
    terr = calc_train_error(X_train,Y_train,ridge)
    verr = calc_validation_error(X_validation,Y_validation,ridge)
    total_error =np.abs(terr-verr)
    error[parameter]= total_error
    p= min(error,key = error.get)
    print("{:.3f}        {:.3f}".format(parameter,error[parameter]))
    
print("Best parameter after validation: {:.3f}".format(p))
# Out:
# Parameter   RMSE Error
# -------------------------
# 0.010        183.869
# 0.111        183.828
# 0.212        183.786
# 0.313        183.743
# 0.414        183.697
# 0.515        183.650
# 0.615        183.602
# 0.716        183.552
# 0.817        183.500
# 0.918        183.447
# 1.019        183.393
# 1.120        183.337
# 1.221        183.279
# 1.322        183.220
# 1.423        183.160
# 1.524        183.098
# 1.625        183.035
# 1.725        182.970
# 1.826        182.904
# 1.927        182.837
# 2.028        182.768
# 2.129        182.698
# 2.230        182.626
# 2.331        182.553
# 2.432        182.479
# 2.533        182.403
# 2.634        182.326
# 2.735        182.248
# 2.835        182.169
# 2.936        182.088
# 3.037        182.006
# 3.138        181.923
# 3.239        181.838
# 3.340        181.753
# 3.441        181.666
# 3.542        181.578
# 3.643        181.488
# 3.744        181.398
# 3.845        181.306
# 3.945        181.213
# 4.046        181.119
# 4.147        181.024
# 4.248        180.927
# 4.349        180.830
# 4.450        180.731
# 4.551        180.631
# 4.652        180.531
# 4.753        180.429
# 4.854        180.326
# 4.955        180.222
# 5.055        180.116
# 5.156        180.010
# 5.257        179.903
# 5.358        179.795
# 5.459        179.685
# 5.560        179.575
# 5.661        179.464
# 5.762        179.351
# 5.863        179.238
# 5.964        179.123
# 6.065        179.008
# 6.165        178.892
# 6.266        178.775
# 6.367        178.656
# 6.468        178.537
# 6.569        178.417
# 6.670        178.296
# 6.771        178.174
# 6.872        178.051
# 6.973        177.928
# 7.074        177.803
# 7.175        177.677
# 7.275        177.551
# 7.376        177.424
# 7.477        177.296
# 7.578        177.167
# 7.679        177.037
# 7.780        176.906
# 7.881        176.775
# 7.982        176.642
# 8.083        176.509
# 8.184        176.375
# 8.285        176.240
# 8.385        176.105
# 8.486        175.969
# 8.587        175.831
# 8.688        175.694
# 8.789        175.555
# 8.890        175.415
# 8.991        175.275
# 9.092        175.134
# 9.193        174.993
# 9.294        174.850
# 9.395        174.707
# 9.495        174.563
# 9.596        174.419
# 9.697        174.274
# 9.798        174.128
# 9.899        173.981
# 10.000        173.834
# Best parameter after validation: 10.000

# %% [markdown]
# Error plot of training and validation for finding best parameter of ridge regression.

# %%
#plot of error
def plotErr(select,X_train,Y_train,para_range,X_validation,Y_validation):   
    #Setup arrays to store training and test accuracies
    para = np.linspace(0.01,para_range,100)
    train_accuracy =np.empty(len(para))
    test_accuracy = np.empty(len(para))

    
    
    for i,k in enumerate(para):
        mod = [Ridge(fit_intercept=True, alpha=k),RandomForestRegressor(max_depth=k, random_state=0),SVR(C=k, epsilon=0.2)]
        m = mod[select]
        m.fit(X_train,Y_train)
        train_accuracy[i]= calc_train_error(X_train, Y_train, m)
        test_accuracy[i] = calc_validation_error(X_validation, Y_validation,m)
       

    #Generate plot
    plt.figure()
    plt.figure(figsize=(8,8))
    plt.title('error plot for training and validation')
    plt.plot(para, test_accuracy, label='validation error')
    plt.plot(para, train_accuracy, label='train error')
    plt.legend()
    plt.xlabel('Value of alpha')
    plt.ylabel('RMSE')
    plt.show()
print("[Stratified Holdout][Ridge Regression]")    
plotErr(0,X_train,Y_train,10,X_validation,Y_validation)
# Out:
# [Stratified Holdout][Ridge Regression]

# %%
# Create ridge regression model
ridge = Ridge(fit_intercept=True, alpha=p)

# %%
# Train the model using the training set
ridge.fit(X_train,Y_train)
# Out:
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
# Compute RMSE on training data
p = ridge.predict(X_train)
err = p-Y_train
total_error = np.dot(err,err)
rmse_train = np.sqrt(total_error/len(p))
print("[stratified Holdout][Ridge Regression]\nTraining error : {:.2f}".format(rmse_train))
# Out:
# [stratified Holdout][Ridge Regression]
# Training error : 4522.67

# %%
#Compute RMSE on validation data
p = ridge.predict(X_validation)
err = p-Y_validation
total_error = np.dot(err,err)
rmse_validation = np.sqrt(total_error/len(p))
print("[Stratified Holdout][Ridge Regression]\nValidation error : {:.2f}".format(rmse_validation))
#accuracy = p.score(X_validation,Y_validation)
# Out:
# [Stratified Holdout][Ridge Regression]
# Validation error : 4348.83

# %%
#Compute RMSE on test data
p = ridge.predict(X_test)
err = p-Y_test
total_error = np.dot(err,err)
rmse_test = np.sqrt(total_error/len(p))
holdoutStf.append(rmse_test)
print("[Stratified Holdout][Ridge Regression]\ntest error : {:.2f}".format(rmse_test))
# Out:
# [Stratified Holdout][Ridge Regression]
# test error : 5520.10

# %%
print("[Stratified Holdout][Ridge Regression]")
model_scatter_plot(p,Y_test)
# Out:
# [Stratified Holdout][Ridge Regression]

# %% [markdown]
# ### <a id="8-2Ba">[Stratified Holdout] Residual Plot for Ridge Regression

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Stratified Holdout] Residual Plot for Ridge Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,p) ## regression Residual Plot for Ridge Regression model using bootstrapping

# %% [markdown]
# ### <a id="8.2C"> C. [Stratified Holdout method]Random Forest </a>

# %% [markdown]
# **Hyperparameter tuning ** : parameter "max depth"  for random forest using validation set

# %%
#hyperparameters
para=np.arange(2,100,1)
error=dict()

#tuning hyperparameter
print("Parameter   RMSE Error")
print("-"*25)
for parameter in para:
    regr = RandomForestRegressor(max_depth=parameter, random_state=0)
    regr.fit(X_train,Y_train)
    
    terr = calc_train_error(X_train,Y_train,regr)
    verr = calc_validation_error(X_validation,Y_validation,regr)
    total_error =np.abs(terr-verr)
    error[parameter]= total_error
    p= min(error,key = error.get)
    print("{:.3f}        {:.3f}".format(parameter,error[parameter]))
    
print("Best parameter after validation: {:.3f}".format(p))
# Out:
# Parameter   RMSE Error
# -------------------------
# 2.000        310.739
# 3.000        273.890
# 4.000        208.146
# 5.000        93.264
# 6.000        671.655
# 7.000        971.360
# 8.000        1390.185
# 9.000        1831.872
# 10.000        2204.163
# 11.000        2332.769
# 12.000        2521.739
# 13.000        2594.469
# 14.000        2586.769
# 15.000        2612.264
# 16.000        2644.877
# 17.000        2634.125
# 18.000        2720.989
# 19.000        2715.003
# 20.000        2684.954
# 21.000        2685.329
# 22.000        2685.329
# 23.000        2685.329
# 24.000        2685.329
# 25.000        2685.329
# 26.000        2685.329
# 27.000        2685.329
# 28.000        2685.329
# 29.000        2685.329
# 30.000        2685.329
# 31.000        2685.329
# 32.000        2685.329
# 33.000        2685.329
# 34.000        2685.329
# 35.000        2685.329
# 36.000        2685.329
# 37.000        2685.329
# 38.000        2685.329
# 39.000        2685.329
# 40.000        2685.329
# 41.000        2685.329
# 42.000        2685.329
# 43.000        2685.329
# 44.000        2685.329
# 45.000        2685.329
# 46.000        2685.329
# 47.000        2685.329
# 48.000        2685.329
# 49.000        2685.329
# 50.000        2685.329
# 51.000        2685.329
# 52.000        2685.329
# 53.000        2685.329
# 54.000        2685.329
# 55.000        2685.329
# 56.000        2685.329
# 57.000        2685.329
# 58.000        2685.329
# 59.000        2685.329
# 60.000        2685.329
# 61.000        2685.329
# 62.000        2685.329
# 63.000        2685.329
# 64.000        2685.329
# 65.000        2685.329
# 66.000        2685.329
# 67.000        2685.329
# 68.000        2685.329
# 69.000        2685.329
# 70.000        2685.329
# 71.000        2685.329
# 72.000        2685.329
# 73.000        2685.329
# 74.000        2685.329
# 75.000        2685.329
# 76.000        2685.329
# 77.000        2685.329
# 78.000        2685.329
# 79.000        2685.329
# 80.000        2685.329
# 81.000        2685.329
# 82.000        2685.329
# 83.000        2685.329
# 84.000        2685.329
# 85.000        2685.329
# 86.000        2685.329
# 87.000        2685.329
# 88.000        2685.329
# 89.000        2685.329
# 90.000        2685.329
# 91.000        2685.329
# 92.000        2685.329
# 93.000        2685.329
# 94.000        2685.329
# 95.000        2685.329
# 96.000        2685.329
# 97.000        2685.329
# 98.000        2685.329
# 99.000        2685.329
# Best parameter after validation: 5.000

# %%
print("[Stratified Holdout][Random Forest]")
plotErr(1,X_train,Y_train,100,X_validation,Y_validation)
# Out:
# [Stratified Holdout][Random Forest]

# %%
# Create random forest regression model
regr = RandomForestRegressor(max_depth=p, random_state=0)

# Train the model using the training set
regr.fit(X_train,Y_train)

# Compute RMSE on training data
p = regr.predict(X_train)
err = p-Y_train
total_error = np.dot(err,err)
rmse_train = np.sqrt(total_error/len(p))
print("[stratified Holdout][Random Forest]\nTraining error : {:.2f}".format(rmse_train))

#Compute RMSE on validation data
p = regr.predict(X_validation)
err = p-Y_validation
total_error = np.dot(err,err)
rmse_validation = np.sqrt(total_error/len(p))
print("Validation error : {:.2f}".format(rmse_validation))
#accuracy = p.score(X_validation,Y_validation)
# Out:
# [stratified Holdout][Random Forest]
# Training error : 3878.18
# Validation error : 3971.45

# %%
#Compute RMSE on test data
p = regr.predict(X_test)
err = p-Y_test
total_error = np.dot(err,err)
rmse_test = np.sqrt(total_error/len(p))
holdoutStf.append(rmse_test)
print("[Stratified Holdout][Random Forest]\nTest error : {:.2f}".format(rmse_test))
# Out:
# [Stratified Holdout][Random Forest]
# Test error : 5510.90

# %%
print("[Stratified Holdout][Random Forest]")
model_scatter_plot(p,Y_test)
# Out:
# [Stratified Holdout][Random Forest]

# %% [markdown]
# ### <a id="8-2Ca"> [Stratified Holdout] Residual Plot for Random Forest </a>

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Stratified Holdout] Residual Plot for Random Forest', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,p) ## regression Residual Plot for Random Forest model using bootstrapping

# %% [markdown]
# ### <a id="8.2D"> D. [Stratified Holdout method]Support Vector Regression </a>

# %% [markdown]
# **Hyperparameter tuning ** : parameter "C"  for support vector regression using validation set

# %%
#hyperparameters
para=np.linspace(1,10,100)
error=dict()

#tuning hyperparameter
print("Parameter   RMSE Error")
print("-"*25)
for parameter in para:
    sv = SVR(C=parameter)
    sv.fit(X_train,Y_train)
    
    terr = calc_train_error(X_train,Y_train,sv)
    verr = calc_validation_error(X_validation,Y_validation,sv)
    total_error =np.abs(terr-verr)
    error[parameter]= total_error
    p= min(error,key = error.get)
    print("{:.3f}        {:.3f}".format(parameter,error[parameter]))
    
print("Best parameter after validation: {:.3f}".format(p))
# Out:
# Parameter   RMSE Error
# -------------------------
# 1.000        204.817
# 1.091        204.974
# 1.182        205.168
# 1.273        205.371
# 1.364        205.575
# 1.455        205.778
# 1.545        205.981
# 1.636        206.184
# 1.727        206.383
# 1.818        206.579
# 1.909        206.770
# 2.000        206.960
# 2.091        207.151
# 2.182        207.336
# 2.273        207.517
# 2.364        207.696
# 2.455        207.862
# 2.545        208.029
# 2.636        208.195
# 2.727        208.362
# 2.818        208.528
# 2.909        208.695
# 3.000        208.861
# 3.091        209.027
# 3.182        209.194
# 3.273        209.360
# 3.364        209.527
# 3.455        209.693
# 3.545        209.859
# 3.636        210.026
# 3.727        210.192
# 3.818        210.358
# 3.909        210.525
# 4.000        210.691
# 4.091        210.857
# 4.182        211.024
# 4.273        211.200
# 4.364        211.392
# 4.455        211.584
# 4.545        211.797
# 4.636        212.025
# 4.727        212.252
# 4.818        212.480
# 4.909        212.708
# 5.000        212.936
# 5.091        213.164
# 5.182        213.391
# 5.273        213.619
# 5.364        213.847
# 5.455        214.075
# 5.545        214.302
# 5.636        214.530
# 5.727        214.755
# 5.818        214.957
# 5.909        215.159
# 6.000        215.362
# 6.091        215.564
# 6.182        215.766
# 6.273        215.968
# 6.364        216.164
# 6.455        216.355
# 6.545        216.547
# 6.636        216.738
# 6.727        216.930
# 6.818        217.122
# 6.909        217.313
# 7.000        217.505
# 7.091        217.696
# 7.182        217.888
# 7.273        218.080
# 7.364        218.271
# 7.455        218.463
# 7.545        218.655
# 7.636        218.846
# 7.727        219.038
# 7.818        219.229
# 7.909        219.421
# 8.000        219.613
# 8.091        219.793
# 8.182        219.971
# 8.273        220.149
# 8.364        220.334
# 8.455        220.525
# 8.545        220.718
# 8.636        220.907
# 8.727        221.100
# 8.818        221.292
# 8.909        221.471
# 9.000        221.653
# 9.091        221.844
# 9.182        222.035
# 9.273        222.224
# 9.364        222.407
# 9.455        222.591
# 9.545        222.774
# 9.636        222.957
# 9.727        223.141
# 9.818        223.324
# 9.909        223.507
# 10.000        223.691
# Best parameter after validation: 1.000

# %%
print("[Stratified Holdout][Support Vector Regression]")
plotErr(2,X_train,Y_train,100,X_validation,Y_validation)
# Out:
# [Stratified Holdout][Support Vector Regression]

# %%
# Create support vector regression model
sv = SVR(C=10)

# Train the model using the training set
sv.fit(X_train,Y_train)

# Compute RMSE on training data
p = sv.predict(X_train)
err = p-Y_train
total_error = np.dot(err,err)
rmse_train = np.sqrt(total_error/len(p))
print("[Stratified Holdout][Support Vector Regressor]\nTraining error : {:.2f}".format(rmse_train))

#Compute RMSE on validation data
p = sv.predict(X_validation)
err = p-Y_validation
total_error = np.dot(err,err)
rmse_validation = np.sqrt(total_error/len(p))
print("Validation error : {:.2f}".format(rmse_validation))
#accuracy = p.score(X_validation,Y_validation)
# Out:
# [Stratified Holdout][Support Vector Regressor]
# Training error : 7189.74
# Validation error : 7413.44

# %%
#Compute RMSE on test data
p = sv.predict(X_test)
err = p-Y_test
total_error = np.dot(err,err)
rmse_test = np.sqrt(total_error/len(p))
holdoutStf.append(rmse_test)
print("[Stratified Holdout][Support Vector regressor]\nTest error : {:.2f}".format(rmse_test))
# Out:
# [Stratified Holdout][Support Vector regressor]
# Test error : 7946.23

# %%
print("[Stratified Holdout][Support Vector Regression]")
model_scatter_plot(p,Y_test)
# Out:
# [Stratified Holdout][Support Vector Regression]

# %% [markdown]
# ### <a id="8-2Ca">[Stratified Holdout] Residual Plot for Support Vector Regression

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Stratified Holdout] Residual Plot for Support Vector Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,p) ## regression Residual Plot for Support Vector Regression model using bootstrapping

# %% [markdown]
# ## <a id="8-3"> 8.3 Stratified k-folds cross-validation </a>

# %% [markdown]
# Stratified K-Folds cross-validator
# Provides train/test indices to split data in train/test sets.
# This cross-validation object is a variation of KFold that returns stratified folds. The folds are made by preserving the percentage of samples for each class.

# %%
from sklearn import model_selection
stratifiedkfold=[]
del X_str["charges"]
del X_str["charge_groups"]
num_of_splits=5
def stratifiedKFold (model): 
    kf = model_selection.StratifiedKFold(n_splits=num_of_splits,shuffle=True)
    pred_test_full =0
    cv_score =[]
    i=1
    for train_index,test_index in kf.split(X_str,y_str):
        print('{} of StratifiedKFold {}'.format(i,kf.n_splits))
        
        xtr,xvl = X_intermediateS.iloc[train_index],X_intermediateS.iloc[test_index]
        ytr,yvl = Y_intermediateS.iloc[train_index],Y_intermediateS.iloc[test_index]

        model.fit(xtr,ytr)
        rmse = calc_train_error(xtr,ytr,model)
        print('Train RMSE :{:.2f}'.format(rmse))
        rmse = calc_train_error(xvl,yvl,model)
        print('Validation RMSE :{:.2f}'.format(rmse))
        print('_'*50)
        cv_score.append(rmse)    
        pred_test = model.predict(X_testS)
        pred_test_full +=pred_test
        i+=1
       
    print('Mean Stratified K Fold CV Score : {:.2f}'.format(np.mean(cv_score))) 
    return np.mean(cv_score), pred_test_full

# %% [markdown]
# ### <a id="8.3A"> A. [Stratified k-fold]Linear Regression Model </a>

# %%
linreg = LinearRegression()
err,y_pred=stratifiedKFold (linreg)
stratifiedkfold.append(err)
# Out:
# 1 of StratifiedKFold 5
# Train RMSE :4531.07
# Validation RMSE :4820.91
# __________________________________________________
# 2 of StratifiedKFold 5
# Train RMSE :4660.52
# Validation RMSE :4288.99
# __________________________________________________
# 3 of StratifiedKFold 5
# Train RMSE :4682.19
# Validation RMSE :4196.71
# __________________________________________________
# 4 of StratifiedKFold 5
# Train RMSE :4430.34
# Validation RMSE :5182.87
# __________________________________________________
# 5 of StratifiedKFold 5
# Train RMSE :4598.48
# Validation RMSE :4532.84
# __________________________________________________
# Mean Stratified K Fold CV Score : 4604.46

# %%
y_pred = y_pred/num_of_splits
print("[Stratified K Fold][Linear Regression]")
model_scatter_plot(y_pred,Y_testS)
# Out:
# [Stratified K Fold][Linear Regression]

# %% [markdown]
# ### <a id="8.3Aa"> [Stratified K Fold CV] Residual Plot for Linear Regression

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Stratified K Fold CV] Residual Plot for Linear Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_testS,y_pred) ## regression Residual Plot for linear regression model using bootstrapping

# %% [markdown]
# ### <a id="8.3B"> B. [Stratified k-fold]Ridge Regression </a>

# %%
ridge = Ridge()
err,y_pred=stratifiedKFold (ridge)
stratifiedkfold.append(err)
# Out:
# 1 of StratifiedKFold 5
# Train RMSE :4647.40
# Validation RMSE :4338.67
# __________________________________________________
# 2 of StratifiedKFold 5
# Train RMSE :4409.43
# Validation RMSE :5246.82
# __________________________________________________
# 3 of StratifiedKFold 5
# Train RMSE :4495.97
# Validation RMSE :4933.52
# __________________________________________________
# 4 of StratifiedKFold 5
# Train RMSE :4733.87
# Validation RMSE :3945.44
# __________________________________________________
# 5 of StratifiedKFold 5
# Train RMSE :4620.49
# Validation RMSE :4445.50
# __________________________________________________
# Mean Stratified K Fold CV Score : 4581.99

# %%
y_pred = y_pred/num_of_splits
print("[Stratified K Fold][Ridge Regression]")
model_scatter_plot(y_pred,Y_testS)
# Out:
# [Stratified K Fold][Ridge Regression]

# %% [markdown]
# ### <a id="8.3Ba">[Stratified K Fold CV] Residual Plot for Ridge Regression </a>

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Stratified K Fold CV] Residual Plot for Ridge Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_testS,y_pred) ## regression Residual Plot for Ridge regression model using bootstrapping

# %% [markdown]
# ### <a id="8.3C"> C. [Stratified k-fold]Random Forest </a>

# %%
rf = RandomForestRegressor()
err,y_pred=stratifiedKFold (rf)
stratifiedkfold.append(err)
# Out:
# 1 of StratifiedKFold 5
# Train RMSE :1873.19
# Validation RMSE :4966.32
# __________________________________________________
# 2 of StratifiedKFold 5
# Train RMSE :2139.67
# Validation RMSE :4651.16
# __________________________________________________
# 3 of StratifiedKFold 5
# Train RMSE :2021.55
# Validation RMSE :5488.87
# __________________________________________________
# 4 of StratifiedKFold 5
# Train RMSE :2102.39
# Validation RMSE :4548.55
# __________________________________________________
# 5 of StratifiedKFold 5
# Train RMSE :2165.25
# Validation RMSE :4745.80
# __________________________________________________
# Mean Stratified K Fold CV Score : 4880.14

# %%
y_pred = y_pred/num_of_splits
print("[Stratified K Fold][Random forest]")
model_scatter_plot(y_pred,Y_testS)
# Out:
# [Stratified K Fold][Random forest]

# %% [markdown]
# ### <a id="8.3Ca">[Stratified K Fold CV] Residual Plot for Random Forest

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Stratified K Fold CV] Residual Plot for Random Forest', y=1, size=20) #"size" controls the title size
sns.residplot(Y_testS,y_pred) ## regression Residual Plot for Random Forest model using bootstrapping

# %% [markdown]
# ### <a id="8.3D"> D. [Stratified k-fold]Support Vector Regression </a>

# %%
sv = SVR()
err,y_pred=stratifiedKFold (sv)
stratifiedkfold.append(err)
# Out:
# 1 of StratifiedKFold 5
# Train RMSE :7282.99
# Validation RMSE :7595.72
# __________________________________________________
# 2 of StratifiedKFold 5
# Train RMSE :7409.13
# Validation RMSE :7462.70
# __________________________________________________
# 3 of StratifiedKFold 5
# Train RMSE :7357.30
# Validation RMSE :7419.50
# __________________________________________________
# 4 of StratifiedKFold 5
# Train RMSE :7395.59
# Validation RMSE :7280.48
# __________________________________________________
# 5 of StratifiedKFold 5
# Train RMSE :7433.08
# Validation RMSE :7113.52
# __________________________________________________
# Mean Stratified K Fold CV Score : 7374.38

# %%
y_pred = y_pred/num_of_splits
print("[Stratified K Fold][Support Vector Regression]")
model_scatter_plot(y_pred,Y_testS)
# Out:
# [Stratified K Fold][Support Vector Regression]

# %% [markdown]
# ### <a id="8.3Da">[Stratified K Fold CV] Residual Plot for Support Vector Regression

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Stratified K Fold CV] Residual Plot for Support Vector Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_testS,y_pred) ## regression Residual Plot for Support Vector regression model using bootstrapping

# %% [markdown]
# # <a id="8-4">  8.4 Bootstrapping </a>

# %% [markdown]
# The sample will be selected with replacement using the resample() function. Any rows that were not included in the sample are retrieved and used as the test dataset. Next, a decision tree classifier is fit on the sample and evaluated on the test set, a classification score calculated, and added to a list of scores collected across all the bootstraps.

# %%
from sklearn.utils import resample
#from sklearn.metrics import accuracy_score

bootstra=[]
# load dataset
X_intermediate["charges"]= Y_intermediate
data = X_intermediate
values = data.values

# configure bootstrap
n_iterations = 10 #number of iterations
n_size = int(len(data) * 1) #sample size
# run bootstrap
stats = list()

# %%
def bootstrap(model_name):
    for i in range(n_iterations):
        # prepare train and test sets
        train = resample(values, n_samples=n_size)
        test = np.array([x for x in values if x.tolist() not in train.tolist()])
        # fit model
        model = model_name
        model.fit(train[:,:-1], train[:,-1])
         # evaluate model
        train_pred = model.predict(train[:,:-1])
        mse = mean_squared_error(train[:,-1], train_pred)
        err_train = np.sqrt(mse)
       # err_train = calc_train_error(train[:,-1], train_pred,model)
        test_pred = model.predict(test[:,:-1])
        mse = mean_squared_error(test[:,-1], test_pred)
        err_test = np.sqrt(mse)
        #err_test = calc_train_error(test[:,-1], test_pred,model)
        print("{} of iteration {}".format(i,n_iterations-1))
        print("RMSE for Train : {:.2f}".format(err_train))
        print("RMSE for Validation : {:.2f}".format(err_test))
      #  print(rmse)
        print("-"*50)
        stats.append(err_test)
    print("Average RMSE for Validation : {:.2f}".format(np.mean(stats))) 
    res= (np.mean(stats))
    # plot rmse
    plt.hist(stats)
    plt.show()
    # confidence intervals
    alpha = 0.95
    p = ((1.0-alpha)/2.0) * 100
    lower = max(0.0, np.percentile(stats, p))
    p = (alpha+((1.0-alpha)/2.0)) * 100
    upper = max(1.0, np.percentile(stats, p))
    print('{:.0f} % confidence interval {:.2f} and {:.2f}'.format(alpha*100, lower, upper))
    return np.mean(stats)

# %% [markdown]
# ## <a id="8-4A">  A. [Bootstrapping]Linear Regression Model </a>

# %%
print("[Logistic Regression] The RMSE for each bootstrap iteration: ")
bootstra.append(bootstrap(LinearRegression()))
# Out:
# [Logistic Regression] The RMSE for each bootstrap iteration:
# 0 of iteration 9
# RMSE for Train : 4506.35
# RMSE for Validation : 4305.54
# --------------------------------------------------
# 1 of iteration 9
# RMSE for Train : 4534.97
# RMSE for Validation : 4363.48
# --------------------------------------------------
# 2 of iteration 9
# RMSE for Train : 3924.27
# RMSE for Validation : 5030.20
# --------------------------------------------------
# 3 of iteration 9
# RMSE for Train : 4210.15
# RMSE for Validation : 4881.15
# --------------------------------------------------
# 4 of iteration 9
# RMSE for Train : 4424.17
# RMSE for Validation : 4429.84
# --------------------------------------------------
# 5 of iteration 9
# RMSE for Train : 4391.92
# RMSE for Validation : 4494.99
# --------------------------------------------------
# 6 of iteration 9
# RMSE for Train : 4299.90
# RMSE for Validation : 4265.46
# --------------------------------------------------
# 7 of iteration 9
# RMSE for Train : 4079.42
# RMSE for Validation : 4925.43
# --------------------------------------------------
# 8 of iteration 9
# RMSE for Train : 4251.39
# RMSE for Validation : 4576.97
# --------------------------------------------------
# 9 of iteration 9
# RMSE for Train : 4488.21
# RMSE for Validation : 4442.90
# --------------------------------------------------
# Average RMSE for Validation : 4571.60
# 95 % confidence interval 4274.48 and 5006.63

# %% [markdown]
# Intrepretation: With 95 % probability I can say that my model RMSE error will lie in the range 4274.48  and 5006.63 on testing on unseen dataset in future.

# %% [markdown]
# ### [Bootstrapping][Linear Regression]Scatter plot of true and predicted cost after bootstrapping

# %%
linreg=LinearRegression()
linreg.fit(X_train,Y_train)
pred=linreg.predict(X_test)
mse = mean_squared_error(Y_test,pred)
err_test = np.sqrt(mse)
print("[Bootstrap][Linear Regression]\nRMSE on Test data: {:.2f}".format(err_test))
model_scatter_plot(pred,Y_test)
# Out:
# [Bootstrap][Linear Regression]
# RMSE on Test data: 5487.97

# %% [markdown]
# So, it is now verified with 95% probability that our model Linear Regression will give RMSE in range 4274.48  and 5006.63 , as RMSE on test set is 5487.97 .

# %% [markdown]
# ### <a id="8-4Aa">[Bootstrapping] Residual Plot for Linear Regression

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Bootstrapping] Residual Plot for Linear Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,pred) ## regression Residual Plot for Linear regression model using bootstrapping

# %% [markdown]
# ## <a id="8-4B">  B. [Bootstrapping]Ridge Regression </a>

# %%
print("[Ridge Regression] The RMSE for each bootstrap iteration: ")
bootstra.append(bootstrap(Ridge()))
# Out:
# [Ridge Regression] The RMSE for each bootstrap iteration:
# 0 of iteration 9
# RMSE for Train : 4426.26
# RMSE for Validation : 4511.98
# --------------------------------------------------
# 1 of iteration 9
# RMSE for Train : 4562.07
# RMSE for Validation : 3954.20
# --------------------------------------------------
# 2 of iteration 9
# RMSE for Train : 4583.02
# RMSE for Validation : 4594.02
# --------------------------------------------------
# 3 of iteration 9
# RMSE for Train : 4772.51
# RMSE for Validation : 3805.74
# --------------------------------------------------
# 4 of iteration 9
# RMSE for Train : 4237.62
# RMSE for Validation : 4845.78
# --------------------------------------------------
# 5 of iteration 9
# RMSE for Train : 4292.73
# RMSE for Validation : 4418.58
# --------------------------------------------------
# 6 of iteration 9
# RMSE for Train : 4162.24
# RMSE for Validation : 4706.24
# --------------------------------------------------
# 7 of iteration 9
# RMSE for Train : 4266.62
# RMSE for Validation : 4535.90
# --------------------------------------------------
# 8 of iteration 9
# RMSE for Train : 4747.71
# RMSE for Validation : 3734.17
# --------------------------------------------------
# 9 of iteration 9
# RMSE for Train : 4417.18
# RMSE for Validation : 4610.54
# --------------------------------------------------
# Average RMSE for Validation : 4471.66
# 95 % confidence interval 3768.16 and 4980.44

# %% [markdown]
# Intrepretation: With 95 % probability I can say that my model RMSE error will lie in the range 3768.16 and 4980.44 on testing on unseen dataset in future.

# %% [markdown]
# ### [Bootstrapping][Ridge Regression]Scatter plot of true and predicted cost after bootstrapping

# %%
ridge=Ridge()
ridge.fit(X_train,Y_train)
pred=ridge.predict(X_test)
mse = mean_squared_error(Y_test,pred)
err_test = np.sqrt(mse)
print("[Bootstrap][Linear Regression]\nRMSE on Test data: {:.2f}".format(err_test))
model_scatter_plot(pred,Y_test)
# Out:
# [Bootstrap][Linear Regression]
# RMSE on Test data: 5489.75

# %% [markdown]
# So, it is now verified with 95% probability that our model Ridge Regression will give RMSE in range <....> to <....> , as RMSE on test set is <....> .

# %% [markdown]
# ### <a id="8-4Ba">[Bootstrapping] Residual Plot for Ridge Regression

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Bootstrapping] Residual Plot for Ridge Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,pred) ## regression Residual Plot for Ridge regression model using bootstrapping

# %% [markdown]
# ## <a id="8-4C">  C. [Bootstrapping]Random Forest </a>

# %%
print("[Random Forest] The RMSE for each bootstrap iteration: ")
bootstra.append(bootstrap(RandomForestRegressor()))
# Out:
# [Random Forest] The RMSE for each bootstrap iteration:
# 0 of iteration 9
# RMSE for Train : 1500.39
# RMSE for Validation : 4670.04
# --------------------------------------------------
# 1 of iteration 9
# RMSE for Train : 1410.14
# RMSE for Validation : 5075.92
# --------------------------------------------------
# 2 of iteration 9
# RMSE for Train : 1342.86
# RMSE for Validation : 5158.29
# --------------------------------------------------
# 3 of iteration 9
# RMSE for Train : 1541.36
# RMSE for Validation : 4918.24
# --------------------------------------------------
# 4 of iteration 9
# RMSE for Train : 1284.80
# RMSE for Validation : 4895.22
# --------------------------------------------------
# 5 of iteration 9
# RMSE for Train : 1346.76
# RMSE for Validation : 4932.61
# --------------------------------------------------
# 6 of iteration 9
# RMSE for Train : 1584.37
# RMSE for Validation : 4755.50
# --------------------------------------------------
# 7 of iteration 9
# RMSE for Train : 1447.01
# RMSE for Validation : 4762.96
# --------------------------------------------------
# 8 of iteration 9
# RMSE for Train : 1485.88
# RMSE for Validation : 4995.99
# --------------------------------------------------
# 9 of iteration 9
# RMSE for Train : 1480.70
# RMSE for Validation : 4913.99
# --------------------------------------------------
# Average RMSE for Validation : 4617.06
# 95 % confidence interval 3786.06 and 5098.58

# %% [markdown]
# Intrepretation: With 95 % probability I can say that my model RMSE error will lie in the range 3786.06 and 5098.58 on testing on unseen dataset in future.

# %% [markdown]
# ### [Bootstrapping][Random Forest]Scatter plot of true and predicted cost after bootstrapping

# %%
rf=RandomForestRegressor()
rf.fit(X_train,Y_train)
pred=rf.predict(X_test)
mse = mean_squared_error(Y_test,pred)
err_test = np.sqrt(mse)
print("[Bootstrap][Random Forest]\nRMSE on Test data: {:.2f}".format(err_test))
model_scatter_plot(pred,Y_test)
# Out:
# [Bootstrap][Random Forest]
# RMSE on Test data: 5633.66

# %% [markdown]
# So, it is now verified with 95% probability that our model Random Forest will give RMSE in range 3786.06 and 5098.58 , as RMSE on test set is 5633.66 .

# %% [markdown]
# ### <a id="8-4Ca">[Bootstrapping] Residual Plot for Random Forest

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Bootstrapping] Residual Plot for Random Forest', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,pred) ## regression Residual Plot for Random Forest model using bootstrapping

# %% [markdown]
# ## <a id="8-4D">  D. [Bootstrapping]Support Vector Regression </a>

# %%
print("[Support Vector Regression] The RMSE for each bootstrap iteration: ")
bootstra.append(bootstrap(SVR()))
# Out:
# [Support Vector Regression] The RMSE for each bootstrap iteration:
# 0 of iteration 9
# RMSE for Train : 7078.30
# RMSE for Validation : 7946.04
# --------------------------------------------------
# 1 of iteration 9
# RMSE for Train : 7020.75
# RMSE for Validation : 7410.80
# --------------------------------------------------
# 2 of iteration 9
# RMSE for Train : 6905.10
# RMSE for Validation : 7636.32
# --------------------------------------------------
# 3 of iteration 9
# RMSE for Train : 7327.37
# RMSE for Validation : 6956.50
# --------------------------------------------------
# 4 of iteration 9
# RMSE for Train : 7312.73
# RMSE for Validation : 7370.96
# --------------------------------------------------
# 5 of iteration 9
# RMSE for Train : 7237.58
# RMSE for Validation : 7366.06
# --------------------------------------------------
# 6 of iteration 9
# RMSE for Train : 7310.29
# RMSE for Validation : 7500.86
# --------------------------------------------------
# 7 of iteration 9
# RMSE for Train : 7551.82
# RMSE for Validation : 7204.61
# --------------------------------------------------
# 8 of iteration 9
# RMSE for Train : 7077.42
# RMSE for Validation : 7769.06
# --------------------------------------------------
# 9 of iteration 9
# RMSE for Train : 7268.83
# RMSE for Validation : 7378.89
# --------------------------------------------------
# Average RMSE for Validation : 5326.30
# 95 % confidence interval 3803.95 and 7773.49

# %% [markdown]
# Intrepretation: With 95 % probability I can say that my model RMSE error will lie in the range 3803.95 and 7773.49 on testing on unseen dataset in future.

# %% [markdown]
# ### [Bootstrapping][Support Vector Regression]Scatter plot of true and predicted cost after bootstrapping

# %%
sv=SVR()
sv.fit(X_train,Y_train)
pred=sv.predict(X_test)
mse = mean_squared_error(Y_test,pred)
err_test = np.sqrt(mse)
print("[Bootstrap][Support Vector Regression]\nRMSE on Test data: {:.2f}".format(err_test))
model_scatter_plot(pred,Y_test)
# Out:
# [Bootstrap][Support Vector Regression]
# RMSE on Test data: 8053.17

# %% [markdown]
# So, it is now verified with 95% probability that our model SVR will give RMSE in range <....> to <....> , as RMSE on test set is <....> .

# %% [markdown]
# ### <a id="8-4Da"> [Bootstrapping] Residual Plot for Support Vector Regression

# %%
plt.figure(figsize=(10,5)) #controls the graph size
plt.title('[Bootstrapping] Residual Plot for Support Vector Regression', y=1, size=20) #"size" controls the title size
sns.residplot(Y_test,pred) ## regression Residual Plot for Support vector regression model using bootstrapping

# %% [markdown]
# ## <a id="9"> 9. Comparison of Performance of Model using Different  Splitting methods  </a>

# %%
# data to plot
n_groups = 4
means_Holdout = (holdoutE[0], holdoutE[1], holdoutE[2], holdoutE[3])
# means_Stratified_Holdout=[4324,2322,5654,3345]
means_Stratified_Holdout = (holdoutStf[0], holdoutStf[1], holdoutStf[2], holdoutStf[3])
means_StratifiedKFold = (stratifiedkfold[0], stratifiedkfold[1], stratifiedkfold[2], stratifiedkfold[3])
means_Bootstrapping = (bootstra[0], bootstra[1], bootstra[2], bootstra[3])
 
# create plot
 
fig,ax = plt.subplots(figsize=(20,8))
index = np.arange(n_groups)
bar_width = 0.21
opacity = 0.8
#plt.figure(figsize=(12,7))
rects1 = plt.bar(index+bar_width, means_Holdout, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Holdout')
 
rects2 = plt.bar(index + 2*bar_width, means_Stratified_Holdout, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Stratified Holdout')

rects3 = plt.bar(index+ 3*bar_width, means_StratifiedKFold, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Stratified K Fold')
rects4 = plt.bar(index+ 4*bar_width, means_Bootstrapping, bar_width,
                 alpha=opacity,
                 color='m',
                 label='Bootstrapping')
 
ax.set_ylim([0,10000])   
plt.xlabel('Model',fontsize=16)
plt.ylabel('RMSE',fontsize=16)
plt.title('Model comparsion on basis of RMSE',fontsize=18)
plt.xticks(index + 2*0.18, ('Linear Regression', 'Ridge Regression ', 'Random Forest','Support Vector Regression'),rotation=20, fontsize=12)
plt.legend(loc='left', bbox_to_anchor=(0.15,1))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '{:.2f}'.format(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
plt.show()

# %% [markdown]
# # <a id="10">10.   Best Regression Model </a>

# %% [markdown]
# > * The best regression model for the given dataset "Insurance"  is Ridge Regression  .
#
#         RMSE is 4471.66 (as observed in above bar plot)
#
# > * The method used to split the dataset into train, vaildation and test set  is  Bootstrapping.
# > * Click here **to see the model** ->>>  <a href="#8-4B">Bootstrapping Ridge Regression</a>
# > * Click here t**o see the Residual  plot and Scatter plot** ->>>   <a href="#8-4Ba"> Residual Plot & Scatter Plot</a>

# %% [markdown]
#    For the **evaluation of the performance of model we choose RMSE **. This because **our dataset is  imbalanced**
#
#    The a*rea under the ROC curve ( AUC ) is a measure of how well a parameter can distinguish between two  groups (churned/retened).*

# %% [markdown]
# Original dataset has 5 features. After doing one hot encoding we have 11 features . But we eliminate features which are collinear and less correlated with target feature .We are left with only five important features.
# Those features are:
#                 cols= ['smoker_yes','age','bmi','children','region_southwest']
